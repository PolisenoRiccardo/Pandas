# %% [markdown]
# <a href="https://colab.research.google.com/github/PolisenoRiccardo/python/blob/main/Correzione_Esercizio_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scrivere le istruzioni per estrarre le informazioni delle richieste riportate più sotto. Rispondere alle richieste in ordine, tre risposte per ogni facciata del foglio protocollo.

# %% [markdown]
# #Richieste fila A

# %% [markdown]
# 1. Scrivere le istruzioni per caricare i dati del file csv (inventare il link e il nome del file) in un dataframe Pandas chiamato “movies”

# %%
import pandas as pd
movies = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
movies.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %% [markdown]
# 2. Visualizzare le ultime 8 righe del dataframe

# %%
movies.tail(8)
# Out:
#                         Genre  Lead Studio  Audience score %  Profitability  \
# Film
# Enchanted              Comedy       Disney                80       4.005737
# Dear John               Drama         Sony                66       4.598800
# Beginners              Comedy  Independent                80       4.471875
# Across the Universe   romance  Independent                84       0.652603
# A Serious Man           Drama    Universal                64       4.382857
# A Dangerous Method      Drama  Independent                89       0.448645
# 27 Dresses             Comedy          Fox                71       5.343622
# (500) Days of Summer   comedy          Fox                81       8.096000
#
#                       Rotten Tomatoes % Worldwide Gross  Year
# Film
# Enchanted                            93        $340.49   2007
# Dear John                            29        $114.97   2010
# Beginners                            84         $14.31   2011
# ...

# %% [markdown]
# 3. visualizzare solo le colonne che contengono il titolo e il genere del film

# %%
movies.iloc[0:][['Film','Genre']]
# Out:
#                                   Film    Genre
# 0           Zack and Miri Make a Porno  Romance
# 1                      Youth in Revolt   Comedy
# 2   You Will Meet a Tall Dark Stranger   Comedy
# 3                         When in Rome   Comedy
# 4                What Happens in Vegas   Comedy
# ..                                 ...      ...
# 72                 Across the Universe  romance
# 73                       A Serious Man    Drama
# 74                  A Dangerous Method    Drama
# 75                          27 Dresses   Comedy
# 76                (500) Days of Summer   comedy
#
# [77 rows x 2 columns]

# %% [markdown]
# 4. visualizzare le righe del dataframe dalla 20 alla 30

# %%
movies[20:31]

# %% [markdown]
# 5. visualizzare il titolo e l’anno dei film che si trovano nelle posizioni 23, 29 e 45

# %%
movies.iloc[[23,29,45]][['Film', 'Year']]
# Out:
#                       Film  Year
# 23      Something Borrowed  2011
# 29  Rachel Getting Married  2008
# 45              Mamma Mia!  2008

# %% [markdown]
# 6. visualizzare i titoli dei film del genere “Animation”

# %%
movies[movies['Genre'] == 'Animation']['Film']
# Out:
# 6                WALL-E
# 22              Tangled
# 64    Gnomeo and Juliet
# 65    Gnomeo and Juliet
# Name: Film, dtype: object

# %%
movies[movies.Genre.isin(['Animation'])]['Film']
# Out:
# 6                WALL-E
# 22              Tangled
# 64    Gnomeo and Juliet
# 65    Gnomeo and Juliet
# Name: Film, dtype: object

# %% [markdown]
# 7. visualizzare i titoli dei film prodotti dalla “Disney” e dalla “20th Century Fox”

# %%
movies[(movies['Lead Studio'] == 'Disney') | (movies['Lead Studio'] == '20th Century Fox')]['Film']
# Out:
# 3                           When in Rome
# 5                    Water For Elephants
# 6                                 WALL-E
# 16                          The Proposal
# 22                               Tangled
# 41                           Monte Carlo
# 60    High School Musical 3: Senior Year
# 64                     Gnomeo and Juliet
# 65                     Gnomeo and Juliet
# 69                             Enchanted
# Name: Film, dtype: object

# %% [markdown]
# 8. visualizzare i titoli dei film usciti dal 2005 al 2010

# %%
movies[(movies['Year'] >= 2005) & (movies['Year'] <= 2010)][['Film', 'Year']]
# Out:
#                                   Film  Year
# 0           Zack and Miri Make a Porno  2008
# 1                      Youth in Revolt  2010
# 2   You Will Meet a Tall Dark Stranger  2010
# 3                         When in Rome  2010
# 4                What Happens in Vegas  2008
# ..                                 ...   ...
# 70                           Dear John  2010
# 72                 Across the Universe  2007
# 73                       A Serious Man  2009
# 75                          27 Dresses  2008
# 76                (500) Days of Summer  2009
#
# [63 rows x 2 columns]

# %% [markdown]
# 9. visualizzare l’ “Audience score %” medio dei film del genere “Drama”

# %%
movies[movies['Genre'] == 'Drama']['Audience score %'].mean()
# Out:
# 67.23076923076923

# %% [markdown]
# 10. diminuire del 10% il valore delle recensioni presenti nel campo “Audience score %”

# %%
movies['Audience score %'] -= movies['Audience score %'] / 10
movies['Audience score %']
# Out:
# 0     56.70
# 1     42.12
# 2     28.35
# 3     35.64
# 4     58.32
#       ...
# 72    68.04
# 73    51.84
# 74    72.09
# 75    57.51
# 76    65.61
# Name: Audience score %, Length: 77, dtype: float64

# %%
movies['Audience score %'] -= movies['Audience score %'] * 0.9

# %% [markdown]
# #Richieste fila B

# %% [markdown]
# 1. Scrivere le istruzioni per caricare i dati del file csv (inventare il link e il nome del file) in un dataframe Pandas chiamato “movies”

# %%
import pandas as pd
movies = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')

# %% [markdown]
# 2. visualizzare le prime 12 righe del dataframe

# %%
movies.head(12)
# Out:
#                                    Film      Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                       Youth in Revolt     Comedy  The Weinstein Company
# 2    You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                          When in Rome     Comedy                 Disney
# 4                 What Happens in Vegas     Comedy                    Fox
# 5                   Water For Elephants      Drama       20th Century Fox
# 6                                WALL-E  Animation                 Disney
# 7                              Waitress    Romance            Independent
# 8                   Waiting For Forever    Romance            Independent
# 9                       Valentine's Day     Comedy           Warner Bros.
# 10  Tyler Perry's Why Did I get Married    Romance            Independent
# 11              Twilight: Breaking Dawn    Romance            Independent
#
# ...

# %% [markdown]
# 3. visualizzare le colonne 3, 4, 5 e 6

# %%
movies.iloc[0:len(movies), 3:7]
# Out:
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross
# 0                 70       1.747542                 64         $41.94
# 1                 52       1.090000                 68         $19.62
# 2                 35       1.211818                 43         $26.66
# 3                 44       0.000000                 15         $43.04
# 4                 72       6.267647                 28        $219.37
# ..               ...            ...                ...             ...
# 72                84       0.652603                 54         $29.37
# 73                64       4.382857                 89         $30.68
# 74                89       0.448645                 79          $8.97
# 75                71       5.343622                 40        $160.31
# 76                81       8.096000                 87         $60.72
#
# [77 rows x 4 columns]

# %% [markdown]
# 4. visualizzare le righe del dataframe che si trovano dalla decima alla trentesima posizione

# %%
movies.iloc[10:31]
# Out:
#                                    Film      Genre   Lead Studio  \
# 10  Tyler Perry's Why Did I get Married    Romance   Independent
# 11              Twilight: Breaking Dawn    Romance   Independent
# 12                             Twilight    Romance        Summit
# 13                       The Ugly Truth     Comedy   Independent
# 14          The Twilight Saga: New Moon      Drama        Summit
# 15             The Time Traveler's Wife      Drama     Paramount
# 16                         The Proposal     Comedy        Disney
# 17               The Invention of Lying     Comedy  Warner Bros.
# 18                   The Heartbreak Kid     Comedy     Paramount
# 19                          The Duchess      Drama     Paramount
# 20  The Curious Case of Benjamin Button    Fantasy  Warner Bros.
# 21                     The Back-up Plan     Comedy           CBS
# 22                              Tangled  Animation        Disney
# ...

# %% [markdown]
# 5. visualizzare il genere e lo studio dei film che si trovano dalla decima alla ventesima posizione

# %%
movies.iloc[10][['Genre', 'Lead Studio']]
# Out:
# Genre              Romance
# Lead Studio    Independent
# Name: 10, dtype: object

# %% [markdown]
# 6. visualizzare le informazioni del film “When in Rome”

# %%
movies[movies['Film'] == 'When in Rome']
# Out:
#            Film   Genre Lead Studio  Audience score %  Profitability  \
# 3  When in Rome  Comedy      Disney                44            0.0
#
#    Rotten Tomatoes % Worldwide Gross  Year
# 3                 15         $43.04   2010

# %% [markdown]
# 7. visualizzare  le informazioni dei film “When in Rome”, “Waitress” e “WALL-E”

# %%
movies[(movies['Film'] == 'When in Rome') | (movies['Film'] == 'Waitress') | (movies['Film'] == 'WALL-E')]
# Out:
#            Film      Genre  Lead Studio  Audience score %  Profitability  \
# 3  When in Rome     Comedy       Disney                44       0.000000
# 6        WALL-E  Animation       Disney                89       2.896019
# 7      Waitress    Romance  Independent                67      11.089742
#
#    Rotten Tomatoes % Worldwide Gross  Year
# 3                 15         $43.04   2010
# 6                 96        $521.28   2008
# 7                 89         $22.18   2007

# %% [markdown]
# 8. visualizzare i titoli dei film che hanno avuto una recensione di Rotten Tomatoes compresa tra 80 e 90

# %%
movies[(movies['Rotten Tomatoes %'] > 80) | (movies['Rotten Tomatoes %'] > 90) ]['Film']
# Out:
# 6                     WALL-E
# 7                   Waitress
# 22                   Tangled
# 29    Rachel Getting Married
# 39      My Week with Marilyn
# 43         Midnight in Paris
# 54                Knocked Up
# 57                 Jane Eyre
# 69                 Enchanted
# 71                 Beginners
# 73             A Serious Man
# 76      (500) Days of Summer
# Name: Film, dtype: object

# %% [markdown]
# 9. visualizzare il valore più alto della recensione di Rotten Tomatoes

# %%
movies['Rotten Tomatoes %'].max()
# Out:
# 96

# %% [markdown]
# 10. aumentare del 10% il valore delle recensioni di Rotten Tomatoes

# %%
movies['Rotten Tomatoes %'] = movies['Rotten Tomatoes %'] + (movies['Rotten Tomatoes %'] / 100 *10)
movies['Rotten Tomatoes %']
# Out:
# 0     70.4
# 1     74.8
# 2     47.3
# 3     16.5
# 4     30.8
#       ...
# 72    59.4
# 73    97.9
# 74    86.9
# 75    44.0
# 76    95.7
# Name: Rotten Tomatoes %, Length: 77, dtype: float64

# %% [markdown]
# #Esercizietti

# %%
movies[movies['Film'].str.contains("the")]
# Out:
#                     Film    Genre   Lead Studio  Audience score %  \
# 25  Sex and the City Two   Comedy  Warner Bros.             3.969
# 26    Sex and the City 2   Comedy  Warner Bros.             3.969
# 27      Sex and the City   Comedy  Warner Bros.             6.561
# 49    Love & Other Drugs   Comedy           Fox             4.455
# 63    Going the Distance   Comedy  Warner Bros.             4.536
# 72   Across the Universe  romance   Independent             6.804
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 25       2.883500                 15        $288.35   2010
# 26       2.883500                 15        $288.35   2010
# 27       7.221796                 49        $415.25   2008
# 49       1.817667                 48         $54.53   2010
# 63       1.314062                 53         $42.05   2010
# 72       0.652603                 54         $29.37   2007

# %%
#Cercare film che iniziano con una stringa specificata

movies[movies['Film'].str.startswith("Th")]

#Cercare film che finiscono con una stringa specificata

movies[movies['Film'].str.endswith("on")]
# Out:
#                                    Film    Genre   Lead Studio  \
# 14          The Twilight Saga: New Moon    Drama        Summit
# 20  The Curious Case of Benjamin Button  Fantasy  Warner Bros.
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 14             6.318      14.196400                 27        $709.82   2009
# 20             6.561       1.783944                 73        $285.43   2008

# %%
#Sort in ordine alfabetico

movies.sort_values(by='Film', ascending=True)
movies.sort_values(by='Film', ascending=False)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
#Ordinare secondo più termini

movies.sort_values(by=['Genre', 'Film'], ascending=True)
# Out:
#                           Film      Genre            Lead Studio  \
# 55                     Killers     Action              Lionsgate
# 64           Gnomeo and Juliet  Animation                 Disney
# 65           Gnomeo and Juliet  Animation                 Disney
# 22                     Tangled  Animation                 Disney
# 6                       WALL-E  Animation                 Disney
# ..                         ...        ...                    ...
# 7                     Waitress    Romance            Independent
# 0   Zack and Miri Make a Porno    Romance  The Weinstein Company
# 43           Midnight in Paris    Romence                   Sony
# 76        (500) Days of Summer     comedy                    Fox
# 72         Across the Universe    romance            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 55             3.645       1.245333                 11         $93.40   2010
# ...
